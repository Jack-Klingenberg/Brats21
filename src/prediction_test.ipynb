# %%
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib

# %%
# These results come from calling python3 run.py -P --smooth --path ./smalldata
# the program then outputs the predictions into the "output" folder and we load it
# using numpy.  

arr = np.load("../output/PRED-2023-05-05T20:28:36.270488/BraTS2021_00000.npy")

# %%
arr.shape
# Out:
# (100, 128, 128, 4)

# %%
fig,axs = plt.subplots(nrows=1, ncols=4, figsize=(25, 10))
axs[0].imshow(arr[50,:,:,0])
axs[1].imshow(arr[50,:,:,1])

axs[2].imshow(arr[50,:,:,2])
axs[3].imshow(arr[50,:,:,3])

# %%
arr = nib.load("../smalldata/BraTS2021_00000/BraTS2021_00000_seg.nii.gz").get_fdata()
fig,axs = plt.subplots(nrows=1, ncols=4, figsize=(25, 10))
axs[0].imshow(arr[:,:,77]==0)
axs[1].imshow(arr[:,:,77]==1)
axs[2].imshow(arr[:,:,77]==2)
axs[3].imshow(arr[:,:,77]==4)

# %%
arr = np.load("/Users/jackklingenberg/C/Brats21/output/PRED-2023-05-05T20:50:04.246334/BraTS2021_00000.npy")
fig,axs = plt.subplots(nrows=1, ncols=4, figsize=(25, 10))
axs[0].imshow(arr[50,:,:,0])
axs[1].imshow(arr[50,:,:,1])
axs[2].imshow(arr[50,:,:,2])
axs[3].imshow(arr[50,:,:,3])
